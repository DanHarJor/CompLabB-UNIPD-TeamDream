# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

from tsfresh import extract_features
from xgboost import XGBClassifier, plot_tree

# %run plot.py
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

# note: here it does not need to be converted to the 3-bit version, a label remains y[i]=0,1,2
y = np.loadtxt(fnamey, dtype=int)
n_class = 3    #  = len(np.unique(y))
print('data: ',N)
# Out:
# data:  10000

# %% [markdown]
# Sub divide large dataset

# %%
import os.path
data_size = [20, 50, 100, 150, 200, 250, 300, 400, 500]

for N in data_size:
    name = 'ts_L60_Z12_A500_DX50_bias5_N'+str(N)+'.dat'
    fnamex='DATA/x_'+name
    fnamey='DATA/y_'+name
    file_found = os.path.isfile(fname)#starts in PWD by default
    if file_found:
        print('split data files already generated')
        #x_ = np.loadtxt(fnamex, delimiter=" ",dtype=float)
        #y_ = np.loadtxt(fnamey, dtype=int
        break
    else:
        print('file not found')
        x_ =x[0:N]
        y_ =y[0:N]
        np.savetxt(fname,x_,fmt="%d")
        fname='DATA/y_'+name
        np.savetxt(fname,y_,fmt="%d")
# Out:
# split data files already generated
