# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  10000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
#remove average value of each sample from its values
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x/400
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 8000   N_val= 2000   L= 60   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.2) ## raised to 0.2
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1
NF = 5

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# ----- Model 1 -----
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 50, 5)             60
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 10, 5)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 4, 5)              180
# _________________________________________________________________
# flatten (Flatten)            (None, 20)                0
# _________________________________________________________________
# dense (Dense)                (None, 12)                252
# _________________________________________________________________
# dropout (Dropout)            (None, 12)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 39
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-03-23 20:13:11.456957: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-23 20:13:11.458094: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-23 20:13:11.458969: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv1D at 0x7f0a5cc1ba90>,
#  <tensorflow.python.keras.layers.pooling.AveragePooling1D at 0x7f0a5c9d5f70>,
#  <tensorflow.python.keras.layers.convolutional.Conv1D at 0x7f0a5c8a3310>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f0a5c9d5cd0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f0a5c8c9b20>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f0a5c88ba30>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f0a5c88b0a0>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 250
EPOCHS = 100

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/100
# 2022-03-23 20:13:12.037356: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-03-23 20:13:12.040157: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2194840000 Hz
# 32/32 - 2s - loss: 1.1166 - accuracy: 0.3440 - val_loss: 1.1055 - val_accuracy: 0.3670
# Epoch 2/100
# 32/32 - 0s - loss: 1.0984 - accuracy: 0.3943 - val_loss: 1.0893 - val_accuracy: 0.3910
# Epoch 3/100
# 32/32 - 0s - loss: 1.0744 - accuracy: 0.4755 - val_loss: 1.0572 - val_accuracy: 0.5305
# Epoch 4/100
# 32/32 - 0s - loss: 1.0298 - accuracy: 0.5691 - val_loss: 0.9961 - val_accuracy: 0.6545
# Epoch 5/100
# 32/32 - 0s - loss: 0.9681 - accuracy: 0.6121 - val_loss: 0.9174 - val_accuracy: 0.6825
# Epoch 6/100
# 32/32 - 0s - loss: 0.8852 - accuracy: 0.6556 - val_loss: 0.8287 - val_accuracy: 0.7190
# Epoch 7/100
# 32/32 - 0s - loss: 0.8130 - accuracy: 0.6773 - val_loss: 0.7522 - val_accuracy: 0.7420
# Epoch 8/100
# 32/32 - 0s - loss: 0.7538 - accuracy: 0.7042 - val_loss: 0.6929 - val_accuracy: 0.7565
# Epoch 9/100
# 32/32 - 0s - loss: 0.7012 - accuracy: 0.7337 - val_loss: 0.6463 - val_accuracy: 0.7930
# Epoch 10/100
# 32/32 - 0s - loss: 0.6660 - accuracy: 0.7559 - val_loss: 0.6011 - val_accuracy: 0.8080
# Epoch 11/100
# 32/32 - 0s - loss: 0.6237 - accuracy: 0.7795 - val_loss: 0.5623 - val_accuracy: 0.8245
# Epoch 12/100
# 32/32 - 0s - loss: 0.5918 - accuracy: 0.7946 - val_loss: 0.5314 - val_accuracy: 0.8410
# Epoch 13/100
# 32/32 - 0s - loss: 0.5559 - accuracy: 0.8199 - val_loss: 0.4946 - val_accuracy: 0.8535
# Epoch 14/100
# 32/32 - 0s - loss: 0.5237 - accuracy: 0.8299 - val_loss: 0.4622 - val_accuracy: 0.8670
# Epoch 15/100
# 32/32 - 0s - loss: 0.4971 - accuracy: 0.8485 - val_loss: 0.4364 - val_accuracy: 0.8865
# Epoch 16/100
# 32/32 - 0s - loss: 0.4750 - accuracy: 0.8539 - val_loss: 0.4114 - val_accuracy: 0.8845
# Epoch 17/100
# 32/32 - 0s - loss: 0.4513 - accuracy: 0.8725 - val_loss: 0.3952 - val_accuracy: 0.8975
# Epoch 18/100
# 32/32 - 0s - loss: 0.4332 - accuracy: 0.8723 - val_loss: 0.3750 - val_accuracy: 0.8965
# Epoch 19/100
# 32/32 - 0s - loss: 0.4133 - accuracy: 0.8771 - val_loss: 0.3534 - val_accuracy: 0.9075
# Epoch 20/100
# 32/32 - 0s - loss: 0.3969 - accuracy: 0.8905 - val_loss: 0.3371 - val_accuracy: 0.9085
# Epoch 21/100
# 32/32 - 0s - loss: 0.3807 - accuracy: 0.8974 - val_loss: 0.3237 - val_accuracy: 0.9155
# Epoch 22/100
# 32/32 - 0s - loss: 0.3630 - accuracy: 0.8999 - val_loss: 0.3134 - val_accuracy: 0.9185
# Epoch 23/100
# 32/32 - 0s - loss: 0.3560 - accuracy: 0.9038 - val_loss: 0.3018 - val_accuracy: 0.9190
# Epoch 24/100
# 32/32 - 0s - loss: 0.3460 - accuracy: 0.9024 - val_loss: 0.2944 - val_accuracy: 0.9225
# Epoch 25/100
# 32/32 - 0s - loss: 0.3375 - accuracy: 0.9069 - val_loss: 0.2824 - val_accuracy: 0.9285
# Epoch 26/100
# 32/32 - 0s - loss: 0.3245 - accuracy: 0.9143 - val_loss: 0.2746 - val_accuracy: 0.9330
# Epoch 27/100
# 32/32 - 0s - loss: 0.3182 - accuracy: 0.9135 - val_loss: 0.2677 - val_accuracy: 0.9315
# Epoch 28/100
# 32/32 - 0s - loss: 0.3122 - accuracy: 0.9155 - val_loss: 0.2647 - val_accuracy: 0.9340
# Epoch 29/100
# 32/32 - 0s - loss: 0.3053 - accuracy: 0.9174 - val_loss: 0.2552 - val_accuracy: 0.9355
# Epoch 30/100
# 32/32 - 0s - loss: 0.2948 - accuracy: 0.9181 - val_loss: 0.2522 - val_accuracy: 0.9345
# Epoch 31/100
# 32/32 - 0s - loss: 0.2859 - accuracy: 0.9249 - val_loss: 0.2435 - val_accuracy: 0.9410
# Epoch 32/100
# 32/32 - 0s - loss: 0.2830 - accuracy: 0.9243 - val_loss: 0.2421 - val_accuracy: 0.9405
# Epoch 33/100
# 32/32 - 0s - loss: 0.2758 - accuracy: 0.9259 - val_loss: 0.2352 - val_accuracy: 0.9415
# Epoch 34/100
# 32/32 - 0s - loss: 0.2755 - accuracy: 0.9270 - val_loss: 0.2330 - val_accuracy: 0.9445
# Epoch 35/100
# 32/32 - 0s - loss: 0.2701 - accuracy: 0.9266 - val_loss: 0.2278 - val_accuracy: 0.9450
# Epoch 36/100
# 32/32 - 0s - loss: 0.2626 - accuracy: 0.9317 - val_loss: 0.2230 - val_accuracy: 0.9470
# Epoch 37/100
# 32/32 - 0s - loss: 0.2573 - accuracy: 0.9340 - val_loss: 0.2223 - val_accuracy: 0.9445
# Epoch 38/100
# 32/32 - 0s - loss: 0.2580 - accuracy: 0.9326 - val_loss: 0.2173 - val_accuracy: 0.9430
# Epoch 39/100
# 32/32 - 0s - loss: 0.2431 - accuracy: 0.9389 - val_loss: 0.2118 - val_accuracy: 0.9500
# Epoch 40/100
# 32/32 - 0s - loss: 0.2471 - accuracy: 0.9383 - val_loss: 0.2093 - val_accuracy: 0.9495
# Epoch 41/100
# 32/32 - 0s - loss: 0.2455 - accuracy: 0.9367 - val_loss: 0.2091 - val_accuracy: 0.9490
# Epoch 42/100
# 32/32 - 0s - loss: 0.2389 - accuracy: 0.9416 - val_loss: 0.2039 - val_accuracy: 0.9470
# Epoch 43/100
# 32/32 - 0s - loss: 0.2331 - accuracy: 0.9419 - val_loss: 0.2100 - val_accuracy: 0.9480
# Epoch 44/100
# 32/32 - 0s - loss: 0.2350 - accuracy: 0.9386 - val_loss: 0.2006 - val_accuracy: 0.9460
# Epoch 45/100
# 32/32 - 0s - loss: 0.2304 - accuracy: 0.9404 - val_loss: 0.1953 - val_accuracy: 0.9515
# Epoch 46/100
# 32/32 - 0s - loss: 0.2317 - accuracy: 0.9410 - val_loss: 0.1939 - val_accuracy: 0.9495
# Epoch 47/100
# 32/32 - 0s - loss: 0.2259 - accuracy: 0.9436 - val_loss: 0.1926 - val_accuracy: 0.9495
# Epoch 48/100
# 32/32 - 0s - loss: 0.2227 - accuracy: 0.9425 - val_loss: 0.1918 - val_accuracy: 0.9480
# Epoch 49/100
# 32/32 - 1s - loss: 0.2186 - accuracy: 0.9424 - val_loss: 0.1953 - val_accuracy: 0.9495
# Epoch 50/100
# 32/32 - 1s - loss: 0.2164 - accuracy: 0.9469 - val_loss: 0.1854 - val_accuracy: 0.9490
# Epoch 51/100
# 32/32 - 1s - loss: 0.2186 - accuracy: 0.9424 - val_loss: 0.1824 - val_accuracy: 0.9515
# Epoch 52/100
# 32/32 - 1s - loss: 0.2116 - accuracy: 0.9460 - val_loss: 0.1829 - val_accuracy: 0.9525
# Epoch 53/100
# 32/32 - 1s - loss: 0.2077 - accuracy: 0.9480 - val_loss: 0.1815 - val_accuracy: 0.9500
# Epoch 54/100
# 32/32 - 1s - loss: 0.2049 - accuracy: 0.9492 - val_loss: 0.1818 - val_accuracy: 0.9540
# Epoch 55/100
# 32/32 - 1s - loss: 0.2048 - accuracy: 0.9449 - val_loss: 0.1770 - val_accuracy: 0.9495
# Epoch 56/100
# 32/32 - 1s - loss: 0.2033 - accuracy: 0.9511 - val_loss: 0.1764 - val_accuracy: 0.9535
# Epoch 57/100
# 32/32 - 1s - loss: 0.2003 - accuracy: 0.9498 - val_loss: 0.1773 - val_accuracy: 0.9490
# Epoch 58/100
# 32/32 - 1s - loss: 0.1949 - accuracy: 0.9507 - val_loss: 0.1718 - val_accuracy: 0.9570
# Epoch 59/100
# 32/32 - 1s - loss: 0.1931 - accuracy: 0.9516 - val_loss: 0.1701 - val_accuracy: 0.9495
# Epoch 60/100
# 32/32 - 1s - loss: 0.1952 - accuracy: 0.9500 - val_loss: 0.1693 - val_accuracy: 0.9565
# Epoch 61/100
# 32/32 - 1s - loss: 0.1922 - accuracy: 0.9523 - val_loss: 0.1670 - val_accuracy: 0.9530
# Epoch 62/100
# 32/32 - 1s - loss: 0.1907 - accuracy: 0.9505 - val_loss: 0.1672 - val_accuracy: 0.9570
# Epoch 63/100
# 32/32 - 1s - loss: 0.1886 - accuracy: 0.9559 - val_loss: 0.1713 - val_accuracy: 0.9540
# Epoch 64/100
# 32/32 - 1s - loss: 0.1894 - accuracy: 0.9509 - val_loss: 0.1634 - val_accuracy: 0.9565
# Epoch 65/100
# 32/32 - 1s - loss: 0.1884 - accuracy: 0.9520 - val_loss: 0.1685 - val_accuracy: 0.9545
# Epoch 66/100
# 32/32 - 1s - loss: 0.1834 - accuracy: 0.9545 - val_loss: 0.1650 - val_accuracy: 0.9510
# Epoch 67/100
# 32/32 - 1s - loss: 0.1835 - accuracy: 0.9546 - val_loss: 0.1592 - val_accuracy: 0.9585
# Epoch 68/100
# 32/32 - 1s - loss: 0.1815 - accuracy: 0.9516 - val_loss: 0.1575 - val_accuracy: 0.9550
# Epoch 69/100
# 32/32 - 1s - loss: 0.1799 - accuracy: 0.9519 - val_loss: 0.1582 - val_accuracy: 0.9560
# Epoch 70/100
# 32/32 - 1s - loss: 0.1800 - accuracy: 0.9538 - val_loss: 0.1580 - val_accuracy: 0.9550
# Epoch 71/100
# 32/32 - 1s - loss: 0.1807 - accuracy: 0.9531 - val_loss: 0.1559 - val_accuracy: 0.9590
# Epoch 72/100
# 32/32 - 1s - loss: 0.1795 - accuracy: 0.9544 - val_loss: 0.1606 - val_accuracy: 0.9545
# Epoch 73/100
# 32/32 - 1s - loss: 0.1774 - accuracy: 0.9561 - val_loss: 0.1554 - val_accuracy: 0.9545
# Epoch 74/100
# 32/32 - 1s - loss: 0.1720 - accuracy: 0.9551 - val_loss: 0.1535 - val_accuracy: 0.9560
# Epoch 75/100
# 32/32 - 1s - loss: 0.1728 - accuracy: 0.9534 - val_loss: 0.1553 - val_accuracy: 0.9545
# Epoch 76/100
# 32/32 - 1s - loss: 0.1660 - accuracy: 0.9557 - val_loss: 0.1495 - val_accuracy: 0.9585
# Epoch 77/100
# 32/32 - 1s - loss: 0.1739 - accuracy: 0.9554 - val_loss: 0.1495 - val_accuracy: 0.9595
# Epoch 78/100
# 32/32 - 1s - loss: 0.1654 - accuracy: 0.9601 - val_loss: 0.1463 - val_accuracy: 0.9610
# Epoch 79/100
# 32/32 - 1s - loss: 0.1650 - accuracy: 0.9571 - val_loss: 0.1503 - val_accuracy: 0.9565
# Epoch 80/100
# 32/32 - 1s - loss: 0.1672 - accuracy: 0.9585 - val_loss: 0.1487 - val_accuracy: 0.9590
# Epoch 81/100
# 32/32 - 1s - loss: 0.1662 - accuracy: 0.9570 - val_loss: 0.1498 - val_accuracy: 0.9560
# Epoch 82/100
# 32/32 - 1s - loss: 0.1671 - accuracy: 0.9556 - val_loss: 0.1495 - val_accuracy: 0.9635
# Epoch 83/100
# 32/32 - 1s - loss: 0.1639 - accuracy: 0.9576 - val_loss: 0.1461 - val_accuracy: 0.9615
# Epoch 84/100
# 32/32 - 1s - loss: 0.1595 - accuracy: 0.9570 - val_loss: 0.1455 - val_accuracy: 0.9600
# Epoch 85/100
# 32/32 - 1s - loss: 0.1594 - accuracy: 0.9590 - val_loss: 0.1494 - val_accuracy: 0.9595
# Epoch 86/100
# 32/32 - 1s - loss: 0.1645 - accuracy: 0.9559 - val_loss: 0.1425 - val_accuracy: 0.9630
# Epoch 87/100
# 32/32 - 1s - loss: 0.1601 - accuracy: 0.9570 - val_loss: 0.1421 - val_accuracy: 0.9630
# Epoch 88/100
# 32/32 - 1s - loss: 0.1609 - accuracy: 0.9571 - val_loss: 0.1502 - val_accuracy: 0.9585
# Epoch 89/100
# 32/32 - 1s - loss: 0.1595 - accuracy: 0.9606 - val_loss: 0.1378 - val_accuracy: 0.9640
# Epoch 90/100
# 32/32 - 1s - loss: 0.1576 - accuracy: 0.9607 - val_loss: 0.1385 - val_accuracy: 0.9625
# Epoch 91/100
# 32/32 - 1s - loss: 0.1527 - accuracy: 0.9610 - val_loss: 0.1377 - val_accuracy: 0.9635
# Epoch 92/100
# 32/32 - 1s - loss: 0.1620 - accuracy: 0.9588 - val_loss: 0.1448 - val_accuracy: 0.9600
# Epoch 93/100
# 32/32 - 1s - loss: 0.1548 - accuracy: 0.9606 - val_loss: 0.1398 - val_accuracy: 0.9630
# Epoch 94/100
# 32/32 - 1s - loss: 0.1535 - accuracy: 0.9590 - val_loss: 0.1365 - val_accuracy: 0.9625
# Epoch 95/100
# 32/32 - 1s - loss: 0.1519 - accuracy: 0.9619 - val_loss: 0.1377 - val_accuracy: 0.9655
# Epoch 96/100
# 32/32 - 1s - loss: 0.1503 - accuracy: 0.9616 - val_loss: 0.1388 - val_accuracy: 0.9615
# Epoch 97/100
# 32/32 - 1s - loss: 0.1533 - accuracy: 0.9611 - val_loss: 0.1319 - val_accuracy: 0.9645
# Epoch 98/100
# 32/32 - 1s - loss: 0.1462 - accuracy: 0.9643 - val_loss: 0.1323 - val_accuracy: 0.9645
# Epoch 99/100
# 32/32 - 1s - loss: 0.1497 - accuracy: 0.9617 - val_loss: 0.1325 - val_accuracy: 0.9645
# Epoch 100/100
# 32/32 - 1s - loss: 0.1445 - accuracy: 0.9628 - val_loss: 0.1360 - val_accuracy: 0.9635

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

BATCH_SIZE2 = 250
EPOCHS2 = 100

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 32/32 - 2s - loss: 1.0674 - accuracy: 0.4364 - val_loss: 0.9575 - val_accuracy: 0.6290
# Epoch 2/100
# 32/32 - 1s - loss: 0.8389 - accuracy: 0.6906 - val_loss: 0.7003 - val_accuracy: 0.7930
# Epoch 3/100
# 32/32 - 1s - loss: 0.6359 - accuracy: 0.7893 - val_loss: 0.5214 - val_accuracy: 0.8550
# Epoch 4/100
# 32/32 - 1s - loss: 0.5069 - accuracy: 0.8510 - val_loss: 0.4287 - val_accuracy: 0.8870
# Epoch 5/100
# 32/32 - 1s - loss: 0.4221 - accuracy: 0.8838 - val_loss: 0.3515 - val_accuracy: 0.9095
# Epoch 6/100
# 32/32 - 1s - loss: 0.3711 - accuracy: 0.9050 - val_loss: 0.3059 - val_accuracy: 0.9250
# Epoch 7/100
# 32/32 - 1s - loss: 0.3268 - accuracy: 0.9161 - val_loss: 0.2787 - val_accuracy: 0.9330
# Epoch 8/100
# 32/32 - 1s - loss: 0.3044 - accuracy: 0.9259 - val_loss: 0.2563 - val_accuracy: 0.9380
# Epoch 9/100
# 32/32 - 1s - loss: 0.2856 - accuracy: 0.9306 - val_loss: 0.2494 - val_accuracy: 0.9375
# Epoch 10/100
# 32/32 - 1s - loss: 0.2704 - accuracy: 0.9351 - val_loss: 0.2322 - val_accuracy: 0.9435
# Epoch 11/100
# 32/32 - 1s - loss: 0.2580 - accuracy: 0.9409 - val_loss: 0.2227 - val_accuracy: 0.9480
# Epoch 12/100
# 32/32 - 1s - loss: 0.2398 - accuracy: 0.9465 - val_loss: 0.2060 - val_accuracy: 0.9570
# Epoch 13/100
# 32/32 - 1s - loss: 0.2348 - accuracy: 0.9438 - val_loss: 0.1972 - val_accuracy: 0.9580
# Epoch 14/100
# 32/32 - 1s - loss: 0.2254 - accuracy: 0.9499 - val_loss: 0.1957 - val_accuracy: 0.9565
# Epoch 15/100
# 32/32 - 1s - loss: 0.2188 - accuracy: 0.9496 - val_loss: 0.1908 - val_accuracy: 0.9590
# Epoch 16/100
# 32/32 - 1s - loss: 0.2072 - accuracy: 0.9536 - val_loss: 0.1756 - val_accuracy: 0.9650
# Epoch 17/100
# 32/32 - 1s - loss: 0.2049 - accuracy: 0.9536 - val_loss: 0.1801 - val_accuracy: 0.9610
# Epoch 18/100
# 32/32 - 1s - loss: 0.1960 - accuracy: 0.9574 - val_loss: 0.1658 - val_accuracy: 0.9660
# Epoch 19/100
# 32/32 - 1s - loss: 0.1842 - accuracy: 0.9609 - val_loss: 0.1594 - val_accuracy: 0.9685
# Epoch 20/100
# 32/32 - 1s - loss: 0.1870 - accuracy: 0.9585 - val_loss: 0.1548 - val_accuracy: 0.9685
# Epoch 21/100
# 32/32 - 1s - loss: 0.1775 - accuracy: 0.9620 - val_loss: 0.1499 - val_accuracy: 0.9715
# Epoch 22/100
# 32/32 - 1s - loss: 0.1742 - accuracy: 0.9631 - val_loss: 0.1462 - val_accuracy: 0.9725
# Epoch 23/100
# 32/32 - 1s - loss: 0.1670 - accuracy: 0.9640 - val_loss: 0.1418 - val_accuracy: 0.9735
# Epoch 24/100
# 32/32 - 1s - loss: 0.1644 - accuracy: 0.9646 - val_loss: 0.1361 - val_accuracy: 0.9730
# Epoch 25/100
# 32/32 - 1s - loss: 0.1601 - accuracy: 0.9668 - val_loss: 0.1346 - val_accuracy: 0.9740
# Epoch 26/100
# 32/32 - 1s - loss: 0.1585 - accuracy: 0.9660 - val_loss: 0.1350 - val_accuracy: 0.9725
# Epoch 27/100
# 32/32 - 1s - loss: 0.1545 - accuracy: 0.9659 - val_loss: 0.1288 - val_accuracy: 0.9740
# Epoch 28/100
# 32/32 - 1s - loss: 0.1524 - accuracy: 0.9684 - val_loss: 0.1291 - val_accuracy: 0.9735
# Epoch 29/100
# 32/32 - 1s - loss: 0.1444 - accuracy: 0.9695 - val_loss: 0.1271 - val_accuracy: 0.9770
# Epoch 30/100
# 32/32 - 1s - loss: 0.1421 - accuracy: 0.9697 - val_loss: 0.1249 - val_accuracy: 0.9745
# Epoch 31/100
# 32/32 - 1s - loss: 0.1424 - accuracy: 0.9681 - val_loss: 0.1246 - val_accuracy: 0.9740
# Epoch 32/100
# 32/32 - 1s - loss: 0.1397 - accuracy: 0.9714 - val_loss: 0.1237 - val_accuracy: 0.9760
# Epoch 33/100
# 32/32 - 1s - loss: 0.1395 - accuracy: 0.9700 - val_loss: 0.1162 - val_accuracy: 0.9765
# Epoch 34/100
# 32/32 - 1s - loss: 0.1341 - accuracy: 0.9706 - val_loss: 0.1224 - val_accuracy: 0.9765
# Epoch 35/100
# 32/32 - 1s - loss: 0.1343 - accuracy: 0.9735 - val_loss: 0.1154 - val_accuracy: 0.9780
# Epoch 36/100
# 32/32 - 1s - loss: 0.1319 - accuracy: 0.9719 - val_loss: 0.1139 - val_accuracy: 0.9785
# Epoch 37/100
# 32/32 - 1s - loss: 0.1274 - accuracy: 0.9741 - val_loss: 0.1122 - val_accuracy: 0.9785
# Epoch 38/100
# 32/32 - 1s - loss: 0.1279 - accuracy: 0.9721 - val_loss: 0.1077 - val_accuracy: 0.9785
# Epoch 39/100
# 32/32 - 1s - loss: 0.1289 - accuracy: 0.9735 - val_loss: 0.1095 - val_accuracy: 0.9795
# Epoch 40/100
# 32/32 - 1s - loss: 0.1267 - accuracy: 0.9730 - val_loss: 0.1074 - val_accuracy: 0.9780
# Epoch 41/100
# 32/32 - 1s - loss: 0.1237 - accuracy: 0.9743 - val_loss: 0.1081 - val_accuracy: 0.9800
# Epoch 42/100
# 32/32 - 1s - loss: 0.1227 - accuracy: 0.9739 - val_loss: 0.1050 - val_accuracy: 0.9800
# Epoch 43/100
# 32/32 - 1s - loss: 0.1174 - accuracy: 0.9760 - val_loss: 0.1040 - val_accuracy: 0.9770
# Epoch 44/100
# 32/32 - 1s - loss: 0.1171 - accuracy: 0.9762 - val_loss: 0.1056 - val_accuracy: 0.9780
# Epoch 45/100
# 32/32 - 1s - loss: 0.1222 - accuracy: 0.9726 - val_loss: 0.1010 - val_accuracy: 0.9800
# Epoch 46/100
# 32/32 - 1s - loss: 0.1183 - accuracy: 0.9746 - val_loss: 0.1005 - val_accuracy: 0.9785
# Epoch 47/100
# 32/32 - 1s - loss: 0.1140 - accuracy: 0.9769 - val_loss: 0.1021 - val_accuracy: 0.9790
# Epoch 48/100
# 32/32 - 1s - loss: 0.1159 - accuracy: 0.9745 - val_loss: 0.0979 - val_accuracy: 0.9810
# Epoch 49/100
# 32/32 - 1s - loss: 0.1127 - accuracy: 0.9760 - val_loss: 0.0969 - val_accuracy: 0.9805
# Epoch 50/100
# 32/32 - 1s - loss: 0.1095 - accuracy: 0.9760 - val_loss: 0.1023 - val_accuracy: 0.9785
# Epoch 51/100
# 32/32 - 1s - loss: 0.1150 - accuracy: 0.9743 - val_loss: 0.0966 - val_accuracy: 0.9815
# Epoch 52/100
# 32/32 - 1s - loss: 0.1094 - accuracy: 0.9761 - val_loss: 0.0967 - val_accuracy: 0.9790
# Epoch 53/100
# 32/32 - 1s - loss: 0.1078 - accuracy: 0.9756 - val_loss: 0.0949 - val_accuracy: 0.9820
# Epoch 54/100
# 32/32 - 1s - loss: 0.1093 - accuracy: 0.9760 - val_loss: 0.0950 - val_accuracy: 0.9810
# Epoch 55/100
# 32/32 - 1s - loss: 0.1035 - accuracy: 0.9784 - val_loss: 0.0925 - val_accuracy: 0.9815
# Epoch 56/100
# 32/32 - 1s - loss: 0.1035 - accuracy: 0.9783 - val_loss: 0.0948 - val_accuracy: 0.9800
# Epoch 57/100
# 32/32 - 1s - loss: 0.1049 - accuracy: 0.9784 - val_loss: 0.0888 - val_accuracy: 0.9820
# Epoch 58/100
# 32/32 - 1s - loss: 0.1026 - accuracy: 0.9785 - val_loss: 0.0896 - val_accuracy: 0.9815
# Epoch 59/100
# 32/32 - 1s - loss: 0.1000 - accuracy: 0.9790 - val_loss: 0.0924 - val_accuracy: 0.9805
# Epoch 60/100
# 32/32 - 1s - loss: 0.1019 - accuracy: 0.9766 - val_loss: 0.0894 - val_accuracy: 0.9810
# Epoch 61/100
# 32/32 - 1s - loss: 0.1022 - accuracy: 0.9796 - val_loss: 0.0872 - val_accuracy: 0.9830
# Epoch 62/100
# 32/32 - 1s - loss: 0.1005 - accuracy: 0.9789 - val_loss: 0.0868 - val_accuracy: 0.9830
# Epoch 63/100
# 32/32 - 1s - loss: 0.0971 - accuracy: 0.9800 - val_loss: 0.0915 - val_accuracy: 0.9795
# Epoch 64/100
# 32/32 - 1s - loss: 0.1002 - accuracy: 0.9765 - val_loss: 0.0869 - val_accuracy: 0.9815
# Epoch 65/100
# 32/32 - 1s - loss: 0.0988 - accuracy: 0.9790 - val_loss: 0.0876 - val_accuracy: 0.9810
# Epoch 66/100
# 32/32 - 1s - loss: 0.0973 - accuracy: 0.9795 - val_loss: 0.0934 - val_accuracy: 0.9785
# Epoch 67/100
# 32/32 - 1s - loss: 0.0970 - accuracy: 0.9795 - val_loss: 0.0882 - val_accuracy: 0.9820
# Epoch 68/100
# 32/32 - 1s - loss: 0.0948 - accuracy: 0.9808 - val_loss: 0.0867 - val_accuracy: 0.9820
# Epoch 69/100
# 32/32 - 1s - loss: 0.0965 - accuracy: 0.9797 - val_loss: 0.0844 - val_accuracy: 0.9820
# Epoch 70/100
# 32/32 - 1s - loss: 0.0911 - accuracy: 0.9799 - val_loss: 0.0848 - val_accuracy: 0.9830
# Epoch 71/100
# 32/32 - 1s - loss: 0.0949 - accuracy: 0.9790 - val_loss: 0.0807 - val_accuracy: 0.9845
# Epoch 72/100
# 32/32 - 1s - loss: 0.0935 - accuracy: 0.9810 - val_loss: 0.0852 - val_accuracy: 0.9820
# Epoch 73/100
# 32/32 - 1s - loss: 0.0932 - accuracy: 0.9793 - val_loss: 0.0816 - val_accuracy: 0.9820
# Epoch 74/100
# 32/32 - 1s - loss: 0.0922 - accuracy: 0.9809 - val_loss: 0.0799 - val_accuracy: 0.9855
# Epoch 75/100
# 32/32 - 1s - loss: 0.0890 - accuracy: 0.9822 - val_loss: 0.0786 - val_accuracy: 0.9835
# Epoch 76/100
# 32/32 - 1s - loss: 0.0904 - accuracy: 0.9803 - val_loss: 0.0797 - val_accuracy: 0.9840
# Epoch 77/100
# 32/32 - 1s - loss: 0.0922 - accuracy: 0.9790 - val_loss: 0.0825 - val_accuracy: 0.9825
# Epoch 78/100
# 32/32 - 1s - loss: 0.0934 - accuracy: 0.9784 - val_loss: 0.0833 - val_accuracy: 0.9830
# Epoch 79/100
# 32/32 - 1s - loss: 0.0874 - accuracy: 0.9816 - val_loss: 0.0810 - val_accuracy: 0.9820
# Epoch 80/100
# 32/32 - 1s - loss: 0.0920 - accuracy: 0.9789 - val_loss: 0.0812 - val_accuracy: 0.9815
# Epoch 81/100
# 32/32 - 1s - loss: 0.0887 - accuracy: 0.9805 - val_loss: 0.0782 - val_accuracy: 0.9820
# Epoch 82/100
# 32/32 - 1s - loss: 0.0877 - accuracy: 0.9787 - val_loss: 0.0798 - val_accuracy: 0.9825
# Epoch 83/100
# 32/32 - 1s - loss: 0.0853 - accuracy: 0.9820 - val_loss: 0.0770 - val_accuracy: 0.9830
# Epoch 84/100
# 32/32 - 1s - loss: 0.0872 - accuracy: 0.9815 - val_loss: 0.0785 - val_accuracy: 0.9835
# Epoch 85/100
# 32/32 - 1s - loss: 0.0853 - accuracy: 0.9810 - val_loss: 0.0757 - val_accuracy: 0.9845
# Epoch 86/100
# 32/32 - 1s - loss: 0.0845 - accuracy: 0.9811 - val_loss: 0.0781 - val_accuracy: 0.9835
# Epoch 87/100
# 32/32 - 1s - loss: 0.0850 - accuracy: 0.9819 - val_loss: 0.0795 - val_accuracy: 0.9835
# Epoch 88/100
# 32/32 - 1s - loss: 0.0846 - accuracy: 0.9808 - val_loss: 0.0811 - val_accuracy: 0.9830
# Epoch 89/100
# 32/32 - 1s - loss: 0.0868 - accuracy: 0.9820 - val_loss: 0.0750 - val_accuracy: 0.9850
# Epoch 90/100
# 32/32 - 1s - loss: 0.0811 - accuracy: 0.9824 - val_loss: 0.0739 - val_accuracy: 0.9845
# Epoch 91/100
# 32/32 - 1s - loss: 0.0822 - accuracy: 0.9819 - val_loss: 0.0830 - val_accuracy: 0.9815
# Epoch 92/100
# 32/32 - 1s - loss: 0.0853 - accuracy: 0.9806 - val_loss: 0.0776 - val_accuracy: 0.9830
# Epoch 93/100
# 32/32 - 1s - loss: 0.0827 - accuracy: 0.9815 - val_loss: 0.0771 - val_accuracy: 0.9825
# Epoch 94/100
# 32/32 - 1s - loss: 0.0808 - accuracy: 0.9814 - val_loss: 0.0781 - val_accuracy: 0.9825
# Epoch 95/100
# 32/32 - 1s - loss: 0.0867 - accuracy: 0.9797 - val_loss: 0.0768 - val_accuracy: 0.9825
# Epoch 96/100
# 32/32 - 1s - loss: 0.0794 - accuracy: 0.9843 - val_loss: 0.0763 - val_accuracy: 0.9835
# Epoch 97/100
# 32/32 - 1s - loss: 0.0825 - accuracy: 0.9821 - val_loss: 0.0737 - val_accuracy: 0.9830
# Epoch 98/100
# 32/32 - 1s - loss: 0.0802 - accuracy: 0.9831 - val_loss: 0.0755 - val_accuracy: 0.9830
# Epoch 99/100
# 32/32 - 1s - loss: 0.0781 - accuracy: 0.9837 - val_loss: 0.0703 - val_accuracy: 0.9860
# Epoch 100/100
# 32/32 - 1s - loss: 0.0782 - accuracy: 0.9821 - val_loss: 0.0727 - val_accuracy: 0.9845

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"]
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

def build_model(reg_val = 0.2, NCONV=1):
    if NCONV==1:
        model.add(Conv1D(filters=NF, kernel_size=11, 
                         kernel_initializer=ini, 
                         kernel_regularizer=reg,
                         activation='relu', 
                         input_shape=input_shape))
        #model.add(MaxPooling1D(3))
        model.add(AveragePooling1D(5))
        model.add(Conv1D(filters=5, kernel_size=7, 
                         activation='relu'))
        model.add(Flatten())
        model.add(Dense(12, activation='relu'))
        model.add(Dropout(0.2))

    if NCONV==2:
        # -----1-----
        model.add(Conv1D(filters=NF, kernel_size=11, 
                         kernel_initializer=ini, 
                         kernel_regularizer=reg, ######## TRY WITHOUT !
                         activation='relu', input_shape=input_shape))
        #model.add(MaxPooling1D(3))
        model.add(AveragePooling1D(5))
        model.add(Flatten())
        model.add(Dense(9, activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(6, activation='relu'))
        model.add(Dropout(0.2))

    model.add(Dense(n_class, activation='softmax')) # softmax !

    opt = tf.keras.optimizers.Adam()

    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])


    # -----2-----
    reg = tf.keras.regularizers.l2(reg_val)
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(n_class, activation='softmax')) # softmax !
    model.compile(loss=loss_fun,
                  optimizer=optimizer,
                  metrics=['accuracy'])
    opt = tf.keras.optimizers.Adam()

    # compile the model
    # categorical_crossentropy, 3 output nodes
    model.compile(loss=keras.losses.categorical_crossentropy, optimizer=opt,metrics=['accuracy'])
    
    return model


# call Keras scikit wrapper
model_gridsearch = KerasClassifier(build_fn=build_model, 
                        epochs=1,
                        batch_size =10, 
                        verbose=0)

# list of allowed optional arguments for the optimizer, see `compile_model()`
reg_val = [0.1, 0.01, 0.001]

# define parameter dictionary
param_grid = dict(reg_val=reg_val)
# call scikit grid search module
grid = GridSearchCV(estimator=model_gridsearch, param_grid=param_grid, n_jobs=1, cv=4)
grid_result = grid.fit(x_train,y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 12 fits failed out of a total of 12.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_2 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_3 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_4 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_5 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_6 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_7 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_8 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_9 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_10 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_11 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_12 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_4354/3610611299.py", line 7, in build_model
#     model.add(Conv1D(filters=NF, kernel_size=11,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py", line 517, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py", line 223, in add
#     output_tensor = layer(self.outputs[0])
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 951, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1090, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2684, in _maybe_build
#     input_spec.assert_input_compatibility(
#   File "/home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py", line 234, in assert_input_compatibility
#     raise ValueError('Input ' + str(input_index) + ' of layer ' +
# ValueError: Input 0 of layer conv1d_13 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 45>()
#      43 # call scikit grid search module
#      44 grid = GridSearchCV(estimator=model_gridsearch, param_grid=param_grid, n_jobs=1, cv=4)
# ---> 45 grid_result = grid.fit(x_train,y_train)
#      47 # summarize results
#      48 print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_search.py:926, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     924 refit_start_time = time.time()
#     925 if y is not None:
# --> 926     self.best_estimator_.fit(X, y, **fit_params)
#     927 else:
#     928     self.best_estimator_.fit(X, **fit_params)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py:223, in KerasClassifier.fit(self, x, y, **kwargs)
#     221   raise ValueError('Invalid shape for y: ' + str(y.shape))
#     222 self.n_classes_ = len(self.classes_)
# --> 223 return super(KerasClassifier, self).fit(x, y, **kwargs)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py:157, in BaseWrapper.fit(self, x, y, **kwargs)
#     154   self.model = self.build_fn(
#     155       **self.filter_sk_params(self.build_fn.__call__))
#     156 else:
# --> 157   self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#     159 if (losses.is_categorical_crossentropy(self.model.loss) and
#     160     len(y.shape) != 2):
#     161   y = to_categorical(y)
#
# Input In [14], in build_model(reg_val)
#       4 def build_model(reg_val = 0.2):
#       5     # -----2-----
#       6     reg = tf.keras.regularizers.l2(reg_val)
# ----> 7     model.add(Conv1D(filters=NF, kernel_size=11,
#       8                      kernel_initializer=ini,
#       9                      kernel_regularizer=reg,
#      10                      activation='relu',
#      11                      input_shape=input_shape))
#      12     #model.add(MaxPooling1D(3))
#      13     model.add(AveragePooling1D(5))
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py:517, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     515 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516 try:
# --> 517   result = method(self, *args, **kwargs)
#     518 finally:
#     519   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py:223, in Sequential.add(self, layer)
#     218     self._has_explicit_input_shape = True
#     220 elif self.outputs:
#     221   # If the model is being built continuously on top of an input layer:
#     222   # refresh its output.
# --> 223   output_tensor = layer(self.outputs[0])
#     224   if len(nest.flatten(output_tensor)) != 1:
#     225     raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:951, in Layer.__call__(self, *args, **kwargs)
#     945 # Functional Model construction mode is invoked when `Layer`s are called on
#     946 # symbolic `KerasTensor`s, i.e.:
#     947 # >> inputs = tf.keras.Input(10)
#     948 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#     949 # >> model = tf.keras.Model(inputs, outputs)
#     950 if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 951   return self._functional_construction_call(inputs, args, kwargs,
#     952                                             input_list)
#     954 # Maintains info about the `Layer.call` stack.
#     955 call_context = base_layer_utils.call_context()
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:1090, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    1086 if keras_tensor.keras_tensors_enabled():
#    1087   with call_context.enter(
#    1088       layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1089     # Check input assumptions set after layer building, e.g. input shape.
# -> 1090     outputs = self._keras_tensor_symbolic_call(
#    1091         inputs, input_masks, args, kwargs)
#    1093     if outputs is None:
#    1094       raise ValueError('A layer\'s `call` method should return a '
#    1095                        'Tensor or a list of Tensors, not None '
#    1096                        '(layer: ' + self.name + ').')
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:822, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     820   return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     821 else:
# --> 822   return self._infer_output_signature(inputs, args, kwargs, input_masks)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:862, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#     856 with backend.name_scope(self._name_scope()):
#     857   with autocast_variable.enable_auto_cast_variables(
#     858       self._compute_dtype_object):
#     859     # Build layer if applicable (if the `build` method has been
#     860     # overridden).
#     861     # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 862     self._maybe_build(inputs)
#     863     outputs = call_fn(inputs, *args, **kwargs)
#     865   self._handle_activity_regularization(inputs, outputs)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:2684, in Layer._maybe_build(self, inputs)
#    2681 def _maybe_build(self, inputs):
#    2682   # Check input assumptions set before layer building, e.g. input rank.
#    2683   if not self.built:
# -> 2684     input_spec.assert_input_compatibility(
#    2685         self.input_spec, inputs, self.name)
#    2686     input_list = nest.flatten(inputs)
#    2687     if input_list and self._dtype_policy.compute_dtype is None:
#
# File ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py:234, in assert_input_compatibility(input_spec, inputs, layer_name)
#     232   ndim = x.shape.rank
#     233   if ndim is not None and ndim < spec.min_ndim:
# --> 234     raise ValueError('Input ' + str(input_index) + ' of layer ' +
#     235                      layer_name + ' is incompatible with the layer: '
#     236                      ': expected min_ndim=' + str(spec.min_ndim) +
#     237                      ', found ndim=' + str(ndim) +
#     238                      '. Full shape received: ' +
#     239                      str(tuple(shape)))
#     240 # Check dtype.
#     241 if spec.dtype is not None:
#
# ValueError: Input 0 of layer conv1d_14 is incompatible with the layer: : expected min_ndim=3, found ndim=2. Full shape received: (None, 3)

# %% [markdown]
# L1: Lasso Regression
# L2: Ridge Regression
#
# $\lamdda$ is the weight we give to the margin
