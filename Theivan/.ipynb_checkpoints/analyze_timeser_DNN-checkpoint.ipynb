# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  10000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
#remove average value of each sample from its values
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x/400
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 8000   N_val= 2000   L= 60   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.2) ## raised to 0.2
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1
NF = 5

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# ----- Model 1 -----
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 50, 5)             60
# _________________________________________________________________
# average_pooling1d_6 (Average (None, 10, 5)             0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 4, 5)              180
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 12)                252
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 3)                 39
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv1D at 0x7f325914c790>,
#  <tensorflow.python.keras.layers.pooling.AveragePooling1D at 0x7f32590f5820>,
#  <tensorflow.python.keras.layers.convolutional.Conv1D at 0x7f32590086a0>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f3258652c70>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f32593dcc70>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f32593efca0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3259802e50>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 250
EPOCHS = 100

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/100
# 32/32 - 1s - loss: 1.1166 - accuracy: 0.3440 - val_loss: 1.1055 - val_accuracy: 0.3670
# Epoch 2/100
# 32/32 - 0s - loss: 1.0984 - accuracy: 0.3943 - val_loss: 1.0893 - val_accuracy: 0.3910
# Epoch 3/100
# 32/32 - 0s - loss: 1.0744 - accuracy: 0.4755 - val_loss: 1.0572 - val_accuracy: 0.5305
# Epoch 4/100
# 32/32 - 0s - loss: 1.0298 - accuracy: 0.5691 - val_loss: 0.9961 - val_accuracy: 0.6545
# Epoch 5/100
# 32/32 - 0s - loss: 0.9681 - accuracy: 0.6121 - val_loss: 0.9174 - val_accuracy: 0.6825
# Epoch 6/100
# 32/32 - 0s - loss: 0.8852 - accuracy: 0.6556 - val_loss: 0.8287 - val_accuracy: 0.7190
# Epoch 7/100
# 32/32 - 0s - loss: 0.8130 - accuracy: 0.6775 - val_loss: 0.7522 - val_accuracy: 0.7420
# Epoch 8/100
# 32/32 - 0s - loss: 0.7538 - accuracy: 0.7045 - val_loss: 0.6927 - val_accuracy: 0.7565
# Epoch 9/100
# 32/32 - 0s - loss: 0.7011 - accuracy: 0.7340 - val_loss: 0.6462 - val_accuracy: 0.7925
# Epoch 10/100
# 32/32 - 0s - loss: 0.6660 - accuracy: 0.7554 - val_loss: 0.6011 - val_accuracy: 0.8075
# Epoch 11/100
# 32/32 - 0s - loss: 0.6236 - accuracy: 0.7795 - val_loss: 0.5623 - val_accuracy: 0.8245
# Epoch 12/100
# 32/32 - 0s - loss: 0.5917 - accuracy: 0.7947 - val_loss: 0.5313 - val_accuracy: 0.8410
# Epoch 13/100
# 32/32 - 0s - loss: 0.5559 - accuracy: 0.8192 - val_loss: 0.4945 - val_accuracy: 0.8535
# Epoch 14/100
# 32/32 - 0s - loss: 0.5238 - accuracy: 0.8300 - val_loss: 0.4622 - val_accuracy: 0.8665
# Epoch 15/100
# 32/32 - 0s - loss: 0.4971 - accuracy: 0.8486 - val_loss: 0.4365 - val_accuracy: 0.8865
# Epoch 16/100
# 32/32 - 0s - loss: 0.4751 - accuracy: 0.8539 - val_loss: 0.4115 - val_accuracy: 0.8855
# Epoch 17/100
# 32/32 - 0s - loss: 0.4514 - accuracy: 0.8726 - val_loss: 0.3954 - val_accuracy: 0.8980
# Epoch 18/100
# 32/32 - 0s - loss: 0.4333 - accuracy: 0.8724 - val_loss: 0.3751 - val_accuracy: 0.8965
# Epoch 19/100
# 32/32 - 0s - loss: 0.4134 - accuracy: 0.8769 - val_loss: 0.3534 - val_accuracy: 0.9075
# Epoch 20/100
# 32/32 - 0s - loss: 0.3971 - accuracy: 0.8903 - val_loss: 0.3372 - val_accuracy: 0.9085
# Epoch 21/100
# 32/32 - 0s - loss: 0.3808 - accuracy: 0.8972 - val_loss: 0.3238 - val_accuracy: 0.9155
# Epoch 22/100
# 32/32 - 0s - loss: 0.3631 - accuracy: 0.8999 - val_loss: 0.3134 - val_accuracy: 0.9185
# Epoch 23/100
# 32/32 - 0s - loss: 0.3560 - accuracy: 0.9039 - val_loss: 0.3018 - val_accuracy: 0.9190
# Epoch 24/100
# 32/32 - 0s - loss: 0.3461 - accuracy: 0.9025 - val_loss: 0.2944 - val_accuracy: 0.9230
# Epoch 25/100
# 32/32 - 0s - loss: 0.3375 - accuracy: 0.9068 - val_loss: 0.2825 - val_accuracy: 0.9280
# Epoch 26/100
# 32/32 - 0s - loss: 0.3246 - accuracy: 0.9143 - val_loss: 0.2748 - val_accuracy: 0.9325
# Epoch 27/100
# 32/32 - 0s - loss: 0.3183 - accuracy: 0.9135 - val_loss: 0.2677 - val_accuracy: 0.9315
# Epoch 28/100
# 32/32 - 0s - loss: 0.3123 - accuracy: 0.9153 - val_loss: 0.2648 - val_accuracy: 0.9340
# Epoch 29/100
# 32/32 - 0s - loss: 0.3054 - accuracy: 0.9174 - val_loss: 0.2553 - val_accuracy: 0.9350
# Epoch 30/100
# 32/32 - 0s - loss: 0.2949 - accuracy: 0.9181 - val_loss: 0.2522 - val_accuracy: 0.9345
# Epoch 31/100
# 32/32 - 0s - loss: 0.2859 - accuracy: 0.9251 - val_loss: 0.2436 - val_accuracy: 0.9410
# Epoch 32/100
# 32/32 - 0s - loss: 0.2830 - accuracy: 0.9245 - val_loss: 0.2421 - val_accuracy: 0.9405
# Epoch 33/100
# 32/32 - 0s - loss: 0.2758 - accuracy: 0.9259 - val_loss: 0.2354 - val_accuracy: 0.9415
# Epoch 34/100
# 32/32 - 0s - loss: 0.2755 - accuracy: 0.9269 - val_loss: 0.2328 - val_accuracy: 0.9440
# Epoch 35/100
# 32/32 - 0s - loss: 0.2701 - accuracy: 0.9266 - val_loss: 0.2278 - val_accuracy: 0.9450
# Epoch 36/100
# 32/32 - 0s - loss: 0.2627 - accuracy: 0.9320 - val_loss: 0.2231 - val_accuracy: 0.9470
# Epoch 37/100
# 32/32 - 0s - loss: 0.2573 - accuracy: 0.9334 - val_loss: 0.2225 - val_accuracy: 0.9445
# Epoch 38/100
# 32/32 - 0s - loss: 0.2581 - accuracy: 0.9329 - val_loss: 0.2173 - val_accuracy: 0.9435
# Epoch 39/100
# 32/32 - 0s - loss: 0.2432 - accuracy: 0.9390 - val_loss: 0.2118 - val_accuracy: 0.9500
# Epoch 40/100
# 32/32 - 0s - loss: 0.2472 - accuracy: 0.9377 - val_loss: 0.2094 - val_accuracy: 0.9495
# Epoch 41/100
# 32/32 - 0s - loss: 0.2456 - accuracy: 0.9367 - val_loss: 0.2089 - val_accuracy: 0.9495
# Epoch 42/100
# 32/32 - 0s - loss: 0.2389 - accuracy: 0.9421 - val_loss: 0.2039 - val_accuracy: 0.9465
# Epoch 43/100
# 32/32 - 0s - loss: 0.2331 - accuracy: 0.9416 - val_loss: 0.2097 - val_accuracy: 0.9480
# Epoch 44/100
# 32/32 - 0s - loss: 0.2349 - accuracy: 0.9386 - val_loss: 0.2007 - val_accuracy: 0.9465
# Epoch 45/100
# 32/32 - 0s - loss: 0.2305 - accuracy: 0.9401 - val_loss: 0.1953 - val_accuracy: 0.9520
# Epoch 46/100
# 32/32 - 0s - loss: 0.2316 - accuracy: 0.9401 - val_loss: 0.1939 - val_accuracy: 0.9495
# Epoch 47/100
# 32/32 - 0s - loss: 0.2260 - accuracy: 0.9436 - val_loss: 0.1927 - val_accuracy: 0.9495
# Epoch 48/100
# 32/32 - 0s - loss: 0.2228 - accuracy: 0.9426 - val_loss: 0.1918 - val_accuracy: 0.9480
# Epoch 49/100
# 32/32 - 0s - loss: 0.2187 - accuracy: 0.9425 - val_loss: 0.1953 - val_accuracy: 0.9495
# Epoch 50/100
# 32/32 - 0s - loss: 0.2165 - accuracy: 0.9465 - val_loss: 0.1854 - val_accuracy: 0.9490
# Epoch 51/100
# 32/32 - 0s - loss: 0.2187 - accuracy: 0.9423 - val_loss: 0.1826 - val_accuracy: 0.9515
# Epoch 52/100
# 32/32 - 0s - loss: 0.2117 - accuracy: 0.9461 - val_loss: 0.1829 - val_accuracy: 0.9530
# Epoch 53/100
# 32/32 - 0s - loss: 0.2077 - accuracy: 0.9479 - val_loss: 0.1815 - val_accuracy: 0.9500
# Epoch 54/100
# 32/32 - 0s - loss: 0.2049 - accuracy: 0.9494 - val_loss: 0.1816 - val_accuracy: 0.9535
# Epoch 55/100
# 32/32 - 0s - loss: 0.2047 - accuracy: 0.9451 - val_loss: 0.1769 - val_accuracy: 0.9505
# Epoch 56/100
# 32/32 - 0s - loss: 0.2032 - accuracy: 0.9513 - val_loss: 0.1763 - val_accuracy: 0.9530
# Epoch 57/100
# 32/32 - 0s - loss: 0.2003 - accuracy: 0.9494 - val_loss: 0.1772 - val_accuracy: 0.9485
# Epoch 58/100
# 32/32 - 0s - loss: 0.1949 - accuracy: 0.9504 - val_loss: 0.1717 - val_accuracy: 0.9570
# Epoch 59/100
# 32/32 - 0s - loss: 0.1931 - accuracy: 0.9516 - val_loss: 0.1700 - val_accuracy: 0.9500
# Epoch 60/100
# 32/32 - 0s - loss: 0.1953 - accuracy: 0.9499 - val_loss: 0.1693 - val_accuracy: 0.9565
# Epoch 61/100
# 32/32 - 0s - loss: 0.1922 - accuracy: 0.9523 - val_loss: 0.1670 - val_accuracy: 0.9535
# Epoch 62/100
# 32/32 - 0s - loss: 0.1907 - accuracy: 0.9506 - val_loss: 0.1670 - val_accuracy: 0.9570
# Epoch 63/100
# 32/32 - 0s - loss: 0.1886 - accuracy: 0.9556 - val_loss: 0.1714 - val_accuracy: 0.9545
# Epoch 64/100
# 32/32 - 0s - loss: 0.1895 - accuracy: 0.9507 - val_loss: 0.1635 - val_accuracy: 0.9575
# Epoch 65/100
# 32/32 - 0s - loss: 0.1884 - accuracy: 0.9517 - val_loss: 0.1686 - val_accuracy: 0.9555
# Epoch 66/100
# 32/32 - 0s - loss: 0.1835 - accuracy: 0.9548 - val_loss: 0.1650 - val_accuracy: 0.9515
# Epoch 67/100
# 32/32 - 0s - loss: 0.1835 - accuracy: 0.9546 - val_loss: 0.1592 - val_accuracy: 0.9580
# Epoch 68/100
# 32/32 - 0s - loss: 0.1815 - accuracy: 0.9517 - val_loss: 0.1575 - val_accuracy: 0.9550
# Epoch 69/100
# 32/32 - 0s - loss: 0.1800 - accuracy: 0.9521 - val_loss: 0.1582 - val_accuracy: 0.9560
# Epoch 70/100
# 32/32 - 0s - loss: 0.1801 - accuracy: 0.9538 - val_loss: 0.1578 - val_accuracy: 0.9550
# Epoch 71/100
# 32/32 - 0s - loss: 0.1805 - accuracy: 0.9529 - val_loss: 0.1559 - val_accuracy: 0.9590
# Epoch 72/100
# 32/32 - 0s - loss: 0.1795 - accuracy: 0.9544 - val_loss: 0.1603 - val_accuracy: 0.9545
# Epoch 73/100
# 32/32 - 0s - loss: 0.1773 - accuracy: 0.9563 - val_loss: 0.1552 - val_accuracy: 0.9545
# Epoch 74/100
# 32/32 - 0s - loss: 0.1720 - accuracy: 0.9551 - val_loss: 0.1533 - val_accuracy: 0.9570
# Epoch 75/100
# 32/32 - 0s - loss: 0.1727 - accuracy: 0.9529 - val_loss: 0.1553 - val_accuracy: 0.9545
# Epoch 76/100
# 32/32 - 0s - loss: 0.1661 - accuracy: 0.9556 - val_loss: 0.1495 - val_accuracy: 0.9585
# Epoch 77/100
# 32/32 - 0s - loss: 0.1739 - accuracy: 0.9554 - val_loss: 0.1496 - val_accuracy: 0.9595
# Epoch 78/100
# 32/32 - 0s - loss: 0.1653 - accuracy: 0.9603 - val_loss: 0.1462 - val_accuracy: 0.9610
# Epoch 79/100
# 32/32 - 0s - loss: 0.1650 - accuracy: 0.9578 - val_loss: 0.1502 - val_accuracy: 0.9565
# Epoch 80/100
# 32/32 - 0s - loss: 0.1671 - accuracy: 0.9585 - val_loss: 0.1485 - val_accuracy: 0.9595
# Epoch 81/100
# 32/32 - 0s - loss: 0.1662 - accuracy: 0.9566 - val_loss: 0.1496 - val_accuracy: 0.9560
# Epoch 82/100
# 32/32 - 0s - loss: 0.1671 - accuracy: 0.9559 - val_loss: 0.1494 - val_accuracy: 0.9630
# Epoch 83/100
# 32/32 - 0s - loss: 0.1640 - accuracy: 0.9576 - val_loss: 0.1462 - val_accuracy: 0.9615
# Epoch 84/100
# 32/32 - 0s - loss: 0.1594 - accuracy: 0.9572 - val_loss: 0.1453 - val_accuracy: 0.9605
# Epoch 85/100
# 32/32 - 0s - loss: 0.1593 - accuracy: 0.9589 - val_loss: 0.1491 - val_accuracy: 0.9595
# Epoch 86/100
# 32/32 - 0s - loss: 0.1643 - accuracy: 0.9561 - val_loss: 0.1423 - val_accuracy: 0.9635
# Epoch 87/100
# 32/32 - 0s - loss: 0.1600 - accuracy: 0.9572 - val_loss: 0.1417 - val_accuracy: 0.9645
# Epoch 88/100
# 32/32 - 0s - loss: 0.1607 - accuracy: 0.9572 - val_loss: 0.1502 - val_accuracy: 0.9585
# Epoch 89/100
# 32/32 - 0s - loss: 0.1594 - accuracy: 0.9605 - val_loss: 0.1377 - val_accuracy: 0.9640
# Epoch 90/100
# 32/32 - 0s - loss: 0.1575 - accuracy: 0.9610 - val_loss: 0.1383 - val_accuracy: 0.9625
# Epoch 91/100
# 32/32 - 0s - loss: 0.1527 - accuracy: 0.9611 - val_loss: 0.1376 - val_accuracy: 0.9630
# Epoch 92/100
# 32/32 - 0s - loss: 0.1621 - accuracy: 0.9588 - val_loss: 0.1445 - val_accuracy: 0.9600
# Epoch 93/100
# 32/32 - 0s - loss: 0.1548 - accuracy: 0.9601 - val_loss: 0.1397 - val_accuracy: 0.9635
# Epoch 94/100
# 32/32 - 0s - loss: 0.1533 - accuracy: 0.9594 - val_loss: 0.1359 - val_accuracy: 0.9625
# Epoch 95/100
# 32/32 - 0s - loss: 0.1518 - accuracy: 0.9617 - val_loss: 0.1374 - val_accuracy: 0.9655
# Epoch 96/100
# 32/32 - 0s - loss: 0.1501 - accuracy: 0.9619 - val_loss: 0.1381 - val_accuracy: 0.9630
# Epoch 97/100
# 32/32 - 0s - loss: 0.1531 - accuracy: 0.9607 - val_loss: 0.1315 - val_accuracy: 0.9650
# Epoch 98/100
# 32/32 - 0s - loss: 0.1460 - accuracy: 0.9641 - val_loss: 0.1319 - val_accuracy: 0.9645
# Epoch 99/100
# 32/32 - 0s - loss: 0.1495 - accuracy: 0.9616 - val_loss: 0.1323 - val_accuracy: 0.9655
# Epoch 100/100
# 32/32 - 0s - loss: 0.1446 - accuracy: 0.9629 - val_loss: 0.1363 - val_accuracy: 0.9635

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

BATCH_SIZE2 = 250
EPOCHS2 = 100

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 32/32 - 1s - loss: 1.0674 - accuracy: 0.4364 - val_loss: 0.9576 - val_accuracy: 0.6285
# Epoch 2/100
# 32/32 - 0s - loss: 0.8390 - accuracy: 0.6908 - val_loss: 0.7006 - val_accuracy: 0.7915
# Epoch 3/100
# 32/32 - 0s - loss: 0.6360 - accuracy: 0.7889 - val_loss: 0.5213 - val_accuracy: 0.8545
# Epoch 4/100
# 32/32 - 0s - loss: 0.5070 - accuracy: 0.8503 - val_loss: 0.4290 - val_accuracy: 0.8870
# Epoch 5/100
# 32/32 - 0s - loss: 0.4230 - accuracy: 0.8829 - val_loss: 0.3532 - val_accuracy: 0.9075
# Epoch 6/100
# 32/32 - 0s - loss: 0.3714 - accuracy: 0.9050 - val_loss: 0.3057 - val_accuracy: 0.9250
# Epoch 7/100
# 32/32 - 0s - loss: 0.3262 - accuracy: 0.9170 - val_loss: 0.2787 - val_accuracy: 0.9340
# Epoch 8/100
# 32/32 - 0s - loss: 0.3028 - accuracy: 0.9268 - val_loss: 0.2553 - val_accuracy: 0.9385
# Epoch 9/100
# 32/32 - 0s - loss: 0.2839 - accuracy: 0.9306 - val_loss: 0.2485 - val_accuracy: 0.9375
# Epoch 10/100
# 32/32 - 0s - loss: 0.2687 - accuracy: 0.9351 - val_loss: 0.2311 - val_accuracy: 0.9405
# Epoch 11/100
# 32/32 - 0s - loss: 0.2568 - accuracy: 0.9405 - val_loss: 0.2219 - val_accuracy: 0.9490
# Epoch 12/100
# 32/32 - 0s - loss: 0.2384 - accuracy: 0.9455 - val_loss: 0.2048 - val_accuracy: 0.9560
# Epoch 13/100
# 32/32 - 0s - loss: 0.2332 - accuracy: 0.9441 - val_loss: 0.1957 - val_accuracy: 0.9585
# Epoch 14/100
# 32/32 - 0s - loss: 0.2242 - accuracy: 0.9494 - val_loss: 0.1950 - val_accuracy: 0.9570
# Epoch 15/100
# 32/32 - 0s - loss: 0.2174 - accuracy: 0.9503 - val_loss: 0.1899 - val_accuracy: 0.9605
# Epoch 16/100
# 32/32 - 0s - loss: 0.2056 - accuracy: 0.9545 - val_loss: 0.1744 - val_accuracy: 0.9645
# Epoch 17/100
# 32/32 - 0s - loss: 0.2029 - accuracy: 0.9550 - val_loss: 0.1786 - val_accuracy: 0.9615
# Epoch 18/100
# 32/32 - 0s - loss: 0.1943 - accuracy: 0.9571 - val_loss: 0.1644 - val_accuracy: 0.9665
# Epoch 19/100
# 32/32 - 0s - loss: 0.1822 - accuracy: 0.9613 - val_loss: 0.1580 - val_accuracy: 0.9695
# Epoch 20/100
# 32/32 - 0s - loss: 0.1849 - accuracy: 0.9600 - val_loss: 0.1534 - val_accuracy: 0.9690
# Epoch 21/100
# 32/32 - 0s - loss: 0.1759 - accuracy: 0.9617 - val_loss: 0.1490 - val_accuracy: 0.9720
# Epoch 22/100
# 32/32 - 0s - loss: 0.1723 - accuracy: 0.9641 - val_loss: 0.1455 - val_accuracy: 0.9715
# Epoch 23/100
# 32/32 - 0s - loss: 0.1654 - accuracy: 0.9647 - val_loss: 0.1411 - val_accuracy: 0.9730
# Epoch 24/100
# 32/32 - 0s - loss: 0.1629 - accuracy: 0.9653 - val_loss: 0.1353 - val_accuracy: 0.9725
# Epoch 25/100
# 32/32 - 0s - loss: 0.1585 - accuracy: 0.9679 - val_loss: 0.1339 - val_accuracy: 0.9735
# Epoch 26/100
# 32/32 - 0s - loss: 0.1577 - accuracy: 0.9655 - val_loss: 0.1344 - val_accuracy: 0.9725
# Epoch 27/100
# 32/32 - 0s - loss: 0.1532 - accuracy: 0.9666 - val_loss: 0.1282 - val_accuracy: 0.9740
# Epoch 28/100
# 32/32 - 0s - loss: 0.1509 - accuracy: 0.9684 - val_loss: 0.1287 - val_accuracy: 0.9735
# Epoch 29/100
# 32/32 - 0s - loss: 0.1433 - accuracy: 0.9706 - val_loss: 0.1260 - val_accuracy: 0.9770
# Epoch 30/100
# 32/32 - 0s - loss: 0.1412 - accuracy: 0.9699 - val_loss: 0.1246 - val_accuracy: 0.9760
# Epoch 31/100
# 32/32 - 0s - loss: 0.1412 - accuracy: 0.9685 - val_loss: 0.1239 - val_accuracy: 0.9745
# Epoch 32/100
# 32/32 - 0s - loss: 0.1389 - accuracy: 0.9720 - val_loss: 0.1231 - val_accuracy: 0.9760
# Epoch 33/100
# 32/32 - 0s - loss: 0.1385 - accuracy: 0.9709 - val_loss: 0.1154 - val_accuracy: 0.9765
# Epoch 34/100
# 32/32 - 0s - loss: 0.1332 - accuracy: 0.9707 - val_loss: 0.1214 - val_accuracy: 0.9765
# Epoch 35/100
# 32/32 - 0s - loss: 0.1335 - accuracy: 0.9721 - val_loss: 0.1149 - val_accuracy: 0.9780
# Epoch 36/100
# 32/32 - 0s - loss: 0.1306 - accuracy: 0.9720 - val_loss: 0.1133 - val_accuracy: 0.9790
# Epoch 37/100
# 32/32 - 0s - loss: 0.1266 - accuracy: 0.9746 - val_loss: 0.1116 - val_accuracy: 0.9785
# Epoch 38/100
# 32/32 - 0s - loss: 0.1274 - accuracy: 0.9722 - val_loss: 0.1072 - val_accuracy: 0.9790
# Epoch 39/100
# 32/32 - 0s - loss: 0.1284 - accuracy: 0.9730 - val_loss: 0.1092 - val_accuracy: 0.9790
# Epoch 40/100
# 32/32 - 0s - loss: 0.1261 - accuracy: 0.9735 - val_loss: 0.1067 - val_accuracy: 0.9775
# Epoch 41/100
# 32/32 - 0s - loss: 0.1231 - accuracy: 0.9755 - val_loss: 0.1076 - val_accuracy: 0.9800
# Epoch 42/100
# 32/32 - 0s - loss: 0.1219 - accuracy: 0.9741 - val_loss: 0.1045 - val_accuracy: 0.9800
# Epoch 43/100
# 32/32 - 0s - loss: 0.1169 - accuracy: 0.9758 - val_loss: 0.1037 - val_accuracy: 0.9770
# Epoch 44/100
# 32/32 - 0s - loss: 0.1165 - accuracy: 0.9761 - val_loss: 0.1049 - val_accuracy: 0.9785
# Epoch 45/100
# 32/32 - 0s - loss: 0.1214 - accuracy: 0.9737 - val_loss: 0.1009 - val_accuracy: 0.9805
# Epoch 46/100
# 32/32 - 0s - loss: 0.1181 - accuracy: 0.9753 - val_loss: 0.1008 - val_accuracy: 0.9780
# Epoch 47/100
# 32/32 - 0s - loss: 0.1135 - accuracy: 0.9766 - val_loss: 0.1017 - val_accuracy: 0.9790
# Epoch 48/100
# 32/32 - 0s - loss: 0.1156 - accuracy: 0.9746 - val_loss: 0.0970 - val_accuracy: 0.9825
# Epoch 49/100
# 32/32 - 0s - loss: 0.1123 - accuracy: 0.9760 - val_loss: 0.0965 - val_accuracy: 0.9810
# Epoch 50/100
# 32/32 - 0s - loss: 0.1091 - accuracy: 0.9764 - val_loss: 0.1018 - val_accuracy: 0.9790
# Epoch 51/100
# 32/32 - 0s - loss: 0.1143 - accuracy: 0.9741 - val_loss: 0.0966 - val_accuracy: 0.9810
# Epoch 52/100
# 32/32 - 0s - loss: 0.1089 - accuracy: 0.9765 - val_loss: 0.0961 - val_accuracy: 0.9790
# Epoch 53/100
# 32/32 - 0s - loss: 0.1073 - accuracy: 0.9761 - val_loss: 0.0944 - val_accuracy: 0.9830
# Epoch 54/100
# 32/32 - 0s - loss: 0.1088 - accuracy: 0.9765 - val_loss: 0.0949 - val_accuracy: 0.9805
# Epoch 55/100
# 32/32 - 0s - loss: 0.1027 - accuracy: 0.9786 - val_loss: 0.0921 - val_accuracy: 0.9830
# Epoch 56/100
# 32/32 - 0s - loss: 0.1030 - accuracy: 0.9791 - val_loss: 0.0945 - val_accuracy: 0.9800
# Epoch 57/100
# 32/32 - 0s - loss: 0.1042 - accuracy: 0.9793 - val_loss: 0.0884 - val_accuracy: 0.9820
# Epoch 58/100
# 32/32 - 0s - loss: 0.1023 - accuracy: 0.9783 - val_loss: 0.0892 - val_accuracy: 0.9815
# Epoch 59/100
# 32/32 - 0s - loss: 0.0993 - accuracy: 0.9786 - val_loss: 0.0916 - val_accuracy: 0.9805
# Epoch 60/100
# 32/32 - 0s - loss: 0.1016 - accuracy: 0.9768 - val_loss: 0.0890 - val_accuracy: 0.9810
# Epoch 61/100
# 32/32 - 0s - loss: 0.1016 - accuracy: 0.9794 - val_loss: 0.0864 - val_accuracy: 0.9830
# Epoch 62/100
# 32/32 - 0s - loss: 0.1000 - accuracy: 0.9790 - val_loss: 0.0862 - val_accuracy: 0.9840
# Epoch 63/100
# 32/32 - 0s - loss: 0.0964 - accuracy: 0.9801 - val_loss: 0.0912 - val_accuracy: 0.9795
# Epoch 64/100
# 32/32 - 0s - loss: 0.0997 - accuracy: 0.9761 - val_loss: 0.0860 - val_accuracy: 0.9815
# Epoch 65/100
# 32/32 - 0s - loss: 0.0981 - accuracy: 0.9790 - val_loss: 0.0867 - val_accuracy: 0.9810
# Epoch 66/100
# 32/32 - 0s - loss: 0.0971 - accuracy: 0.9789 - val_loss: 0.0934 - val_accuracy: 0.9770
# Epoch 67/100
# 32/32 - 0s - loss: 0.0966 - accuracy: 0.9803 - val_loss: 0.0872 - val_accuracy: 0.9820
# Epoch 68/100
# 32/32 - 0s - loss: 0.0944 - accuracy: 0.9809 - val_loss: 0.0857 - val_accuracy: 0.9835
# Epoch 69/100
# 32/32 - 0s - loss: 0.0957 - accuracy: 0.9803 - val_loss: 0.0837 - val_accuracy: 0.9820
# Epoch 70/100
# 32/32 - 0s - loss: 0.0908 - accuracy: 0.9800 - val_loss: 0.0839 - val_accuracy: 0.9830
# Epoch 71/100
# 32/32 - 0s - loss: 0.0948 - accuracy: 0.9791 - val_loss: 0.0802 - val_accuracy: 0.9845
# Epoch 72/100
# 32/32 - 0s - loss: 0.0933 - accuracy: 0.9815 - val_loss: 0.0847 - val_accuracy: 0.9820
# Epoch 73/100
# 32/32 - 0s - loss: 0.0928 - accuracy: 0.9795 - val_loss: 0.0816 - val_accuracy: 0.9815
# Epoch 74/100
# 32/32 - 0s - loss: 0.0918 - accuracy: 0.9806 - val_loss: 0.0796 - val_accuracy: 0.9845
# Epoch 75/100
# 32/32 - 0s - loss: 0.0890 - accuracy: 0.9822 - val_loss: 0.0780 - val_accuracy: 0.9835
# Epoch 76/100
# 32/32 - 0s - loss: 0.0899 - accuracy: 0.9805 - val_loss: 0.0793 - val_accuracy: 0.9840
# Epoch 77/100
# 32/32 - 0s - loss: 0.0916 - accuracy: 0.9791 - val_loss: 0.0821 - val_accuracy: 0.9825
# Epoch 78/100
# 32/32 - 0s - loss: 0.0931 - accuracy: 0.9784 - val_loss: 0.0836 - val_accuracy: 0.9830
# Epoch 79/100
# 32/32 - 0s - loss: 0.0868 - accuracy: 0.9819 - val_loss: 0.0800 - val_accuracy: 0.9855
# Epoch 80/100
# 32/32 - 0s - loss: 0.0913 - accuracy: 0.9796 - val_loss: 0.0807 - val_accuracy: 0.9820
# Epoch 81/100
# 32/32 - 0s - loss: 0.0882 - accuracy: 0.9804 - val_loss: 0.0776 - val_accuracy: 0.9825
# Epoch 82/100
# 32/32 - 0s - loss: 0.0875 - accuracy: 0.9786 - val_loss: 0.0798 - val_accuracy: 0.9825
# Epoch 83/100
# 32/32 - 0s - loss: 0.0851 - accuracy: 0.9819 - val_loss: 0.0769 - val_accuracy: 0.9830
# Epoch 84/100
# 32/32 - 0s - loss: 0.0867 - accuracy: 0.9814 - val_loss: 0.0791 - val_accuracy: 0.9840
# Epoch 85/100
# 32/32 - 0s - loss: 0.0854 - accuracy: 0.9809 - val_loss: 0.0755 - val_accuracy: 0.9845
# Epoch 86/100
# 32/32 - 0s - loss: 0.0843 - accuracy: 0.9812 - val_loss: 0.0783 - val_accuracy: 0.9835
# Epoch 87/100
# 32/32 - 0s - loss: 0.0850 - accuracy: 0.9810 - val_loss: 0.0793 - val_accuracy: 0.9840
# Epoch 88/100
# 32/32 - 0s - loss: 0.0839 - accuracy: 0.9809 - val_loss: 0.0804 - val_accuracy: 0.9825
# Epoch 89/100
# 32/32 - 0s - loss: 0.0863 - accuracy: 0.9822 - val_loss: 0.0748 - val_accuracy: 0.9850
# Epoch 90/100
# 32/32 - 0s - loss: 0.0807 - accuracy: 0.9822 - val_loss: 0.0735 - val_accuracy: 0.9845
# Epoch 91/100
# 32/32 - 0s - loss: 0.0819 - accuracy: 0.9820 - val_loss: 0.0836 - val_accuracy: 0.9810
# Epoch 92/100
# 32/32 - 0s - loss: 0.0853 - accuracy: 0.9809 - val_loss: 0.0771 - val_accuracy: 0.9830
# Epoch 93/100
# 32/32 - 0s - loss: 0.0824 - accuracy: 0.9820 - val_loss: 0.0770 - val_accuracy: 0.9825
# Epoch 94/100
# 32/32 - 0s - loss: 0.0806 - accuracy: 0.9815 - val_loss: 0.0779 - val_accuracy: 0.9830
# Epoch 95/100
# 32/32 - 0s - loss: 0.0862 - accuracy: 0.9799 - val_loss: 0.0761 - val_accuracy: 0.9825
# Epoch 96/100
# 32/32 - 0s - loss: 0.0791 - accuracy: 0.9845 - val_loss: 0.0763 - val_accuracy: 0.9825
# Epoch 97/100
# 32/32 - 0s - loss: 0.0822 - accuracy: 0.9825 - val_loss: 0.0739 - val_accuracy: 0.9830
# Epoch 98/100
# 32/32 - 0s - loss: 0.0795 - accuracy: 0.9837 - val_loss: 0.0749 - val_accuracy: 0.9830
# Epoch 99/100
# 32/32 - 0s - loss: 0.0779 - accuracy: 0.9839 - val_loss: 0.0704 - val_accuracy: 0.9865
# Epoch 100/100
# 32/32 - 0s - loss: 0.0780 - accuracy: 0.9815 - val_loss: 0.0721 - val_accuracy: 0.9845

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"]
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))

# %% [markdown]
# # Studying Performance of CNN Varying amplitude of the patterns
# I generated new datasets with amplitudes of 50, 100, 150,...,1000.
# THE IDEA:
#
# -make a for loop on the datasets varying the amplitude.
#
# -evaluate the first CNN defined and trained above
#
# -make a plot accuracy vs amplitude of the patters

# %%
As = np.array([50*i for i in range(1,61)]) #to numpy array so I can slice index

results = dict()

for A in As:
    ######## LOADING DATA #########
    print(A)
    Z=12
    # number of data samples
    N=10000
    L=60
    DX = 50
    bias = 5
    str0 = f'ts_L{L}_Z{Z}_A{A}_DX{DX}_bias{bias}_N{N}.dat'

    fnamex='DATA/different_amplitudes/x_'+str0
    fnamey='DATA/different_amplitudes/y_'+str0

    x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
    N,L = len(x), len(x[0])

    categ = np.loadtxt(fnamey, dtype=int)
    n_class = 3    # y.argmax() - y.argmin() +1
    print('data: ',N)

    y = np.zeros((N,n_class))
    for i in range(N):
        y[i][categ[i]] = 1.
        
    # Keras wants an additional dimension with a 1 at the end
    x = x.reshape(x.shape[0], L, 1)
    input_shape = (L, 1)
        
    ######## MODEL EVALUATION#########
    results[A] = model.evaluate(x, y, batch_size=BATCH_SIZE) #saving in dictionary
# Out:
# 50
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1479047.7500 - accuracy: 0.3331
# 100
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1466759.1250 - accuracy: 0.3334
# 150
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1478174.7500 - accuracy: 0.3333
# 200
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1457282.5000 - accuracy: 0.3336
# 250
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1530366.0000 - accuracy: 0.3333
# 300
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1485831.6250 - accuracy: 0.3336
# 350
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1519472.0000 - accuracy: 0.3333
# 400
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1496129.8750 - accuracy: 0.3333
# 450
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1499353.7500 - accuracy: 0.3336
# 500
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1508000.8750 - accuracy: 0.3343
# 550
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1537312.3750 - accuracy: 0.3335
# 600
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1477396.0000 - accuracy: 0.3338
# 650
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1485359.5000 - accuracy: 0.3336
# 700
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1512116.6250 - accuracy: 0.3340
# 750
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1475920.1250 - accuracy: 0.3343
# 800
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1496830.5000 - accuracy: 0.3339
# 850
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1485484.5000 - accuracy: 0.3340
# 900
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1520828.6250 - accuracy: 0.3341
# 950
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1499963.3750 - accuracy: 0.3344
# 1000
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1500478.8750 - accuracy: 0.3338
# 1050
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1473913.1250 - accuracy: 0.3342
# 1100
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1472764.1250 - accuracy: 0.3348
# 1150
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1478323.7500 - accuracy: 0.3345
# 1200
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1510772.3750 - accuracy: 0.3349
# 1250
# data:  10000
# 40/40 [==============================] - 0s 4ms/step - loss: 1511334.1250 - accuracy: 0.3349
# 1300
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1525906.3750 - accuracy: 0.3347
# 1350
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1538156.7500 - accuracy: 0.3350
# 1400
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1491459.3750 - accuracy: 0.3349
# 1450
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1484724.7500 - accuracy: 0.3349
# 1500
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1471975.3750 - accuracy: 0.3351
# 1550
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1499305.1250 - accuracy: 0.3348
# 1600
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1520315.6250 - accuracy: 0.3349
# 1650
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1493423.5000 - accuracy: 0.3354
# 1700
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1495351.7500 - accuracy: 0.3352
# 1750
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1488250.6250 - accuracy: 0.3348
# 1800
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1531843.1250 - accuracy: 0.3353
# 1850
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1489452.6250 - accuracy: 0.3352
# 1900
# data:  10000
# 40/40 [==============================] - 0s 3ms/step - loss: 1482569.7500 - accuracy: 0.3354
# 1950
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1465389.0000 - accuracy: 0.3362
# 2000
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1504389.0000 - accuracy: 0.3351
# 2050
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1474113.7500 - accuracy: 0.3357
# 2100
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1518834.8750 - accuracy: 0.3350
# 2150
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1490175.6250 - accuracy: 0.3356
# 2200
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1519410.8750 - accuracy: 0.3356
# 2250
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1510317.5000 - accuracy: 0.3354
# 2300
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1548306.3750 - accuracy: 0.3353
# 2350
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1526309.6250 - accuracy: 0.3355
# 2400
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1495154.5000 - accuracy: 0.3368
# 2450
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1493056.8750 - accuracy: 0.3362
# 2500
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1505380.6250 - accuracy: 0.3355
# 2550
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1510109.1250 - accuracy: 0.3365
# 2600
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1524160.1250 - accuracy: 0.3365
# 2650
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1462705.8750 - accuracy: 0.3366
# 2700
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1478257.0000 - accuracy: 0.3367
# 2750
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1500753.2500 - accuracy: 0.3361
# 2800
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1489295.7500 - accuracy: 0.3365
# 2850
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1511425.0000 - accuracy: 0.3369
# 2900
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1497760.1250 - accuracy: 0.3369
# 2950
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1460967.7500 - accuracy: 0.3375
# 3000
# data:  10000
# 40/40 [==============================] - 0s 2ms/step - loss: 1478290.7500 - accuracy: 0.3371

# %%
performance_df = pd.DataFrame(results)
accuracies = np.array(performance_df.T[1].values)
amplitudes = np.array(performance_df.T[1].index)

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(amplitudes,accuracies, lw=4)

#making plot pretty
plt.xlabel('Pattern Amplitude', fontsize=20)
plt.ylabel('Accuracy of CNN', fontsize=20)

plt.grid()
plt.xticks(size=18)
plt.yticks(size=18)
# Out:
# (array([0.332, 0.333, 0.334, 0.335, 0.336, 0.337, 0.338]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # just playing with linear fit

# %%
from sklearn.linear_model import LinearRegression as linreg

# %%
fit = linreg().fit(X=amplitudes.reshape(-1,1) ,y=accuracies)

# %%
m = fit.coef_ #slope
b = fit.intercept_ #intercept

t = np.linspace(0,3000,3000) # fit x
y_fit = t*m + b # fit y

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(amplitudes,accuracies, lw=4, label='Data') # data

plt.plot(t,y_fit, linestyle='--',color='black', lw=5, label='Linear Fit')

#making plot pretty
plt.xlabel('Pattern Amplitude', fontsize=20)
plt.ylabel('Accuracy of CNN', fontsize=20)

plt.grid()
plt.xticks(size=18)
plt.yticks(size=18)
plt.legend(fontsize=22)

# %%
fit.score(accuracies.reshape(-1,1),amplitudes)
# Out:
# -3.1003402416032957
